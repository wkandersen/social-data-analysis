# %% [markdown]
# # Week 7
#
# This week is a change of pace. No data analysis, no new plot types. Instead, you're going to build a website. Your own corner of the internet where you'll publish the interactive visualizations you've been creating and, starting next week, tell stories with data.
#
# The web is the natural home for interactive data visualization. A Plotly chart inside a Jupyter notebook is useful for *you*; a Plotly chart on a website is useful for *everyone*.

# %% [markdown]
# ## Today
#
# This lecture covers:
#
# 1. **Getting inspired**: Before building, you'll look at how the professionals present data on the web, and get a first taste of HTML right here in the notebook.
# 2. **Setting up GitHub Pages**: You'll create a free website hosted on GitHub and populate it with interactive visualizations from previous weeks.
# 3. **Design and polish**: Using iterative LLM prompting, you'll transform your site from bare-bones HTML into something that looks professional.

# %% [markdown]
# ## Part 1: Before You Build
#
# Before jumping into building a website, let's do two things: get inspired by looking at how the pros present data on the web, and get a feel for the raw material you'll be working with — HTML.

# %% [markdown]
# > *Exercise 1.1*: Inspect the professionals.
# >
# > Visit at least two of the following data visualization / data journalism sites:
# >
# > * [The Pudding](https://pudding.cool/) — visual essays on cultural topics
# > * [Our World in Data](https://ourworldindata.org/) — research and interactive charts on global issues
# > * [The Upshot (NYT)](https://www.nytimes.com/section/upshot) — data-driven journalism
# > * [Flowing Data](https://flowingdata.com/) — visualization projects and tutorials
# >
# > Pick one article or project from each site that you find compelling. For each one, note:
# >
# > * How do they combine text and visualizations? Is it text-then-chart-then-text, or something more integrated?
# > * What design elements catch your eye? (Color scheme, typography, whitespace, layout)
# > * How do they handle interactive vs. static figures? Do all charts need to be interactive, or do some work better as static images?
# > * Write down 2–3 specific design ideas you'd like to steal for your own site.
# >
# > This should be a fast exercise. Spend about 10-20 minutes in total. The goal is to build a visual vocabulary before you start designing.
#
# <div class="alert alert-block alert-info">
# Use your own eyes and brain for this one. The point is developing your own sense of what you think looks good.
# </div>

# %% [markdown]
# ### A taste of HTML
#
# Your website will be built from HTML — the language that web browsers understand. Before we start creating files and pushing them to GitHub, let's play with HTML right here in the notebook.
#
# Jupyter can render HTML directly using `IPython.display.HTML`. This means you can experiment and see results instantly, without leaving the notebook. Try running the cell below (needless to day, this only works if you download the notebook from the `Code` part of the GitHub repo, it won't render in the `.html` version on the course-page):

# %%
from IPython.display import HTML

HTML("""
<div style="font-family: 'Helvetica Neue', Arial, sans-serif; max-width: 600px;
            padding: 30px; background: linear-gradient(135deg, #1a1a2e, #16213e);
            border-radius: 12px; color: white;">
    <h1 style="margin-top: 0; font-size: 28px;">SF Crime Analysis</h1>
    <p style="color: #b0b0c0; line-height: 1.6;">
        An interactive exploration of two decades of crime data in San Francisco —
        uncovering patterns across time, space, and category.
    </p>
    <div style="display: flex; gap: 10px; margin-top: 20px;">
        <a href="#" style="padding: 10px 20px; background: #e94560; color: white;
           text-decoration: none; border-radius: 6px;">Hourly patterns</a>
        <a href="#" style="padding: 10px 20px; background: #0f3460; color: white;
           text-decoration: none; border-radius: 6px;">Crime map</a>
    </div>
</div>
""")
# Out:
# <div style="font-family: 'Helvetica Neue', Arial, sans-serif; max-width: 600px;
#             padding: 30px; background: linear-gradient(135deg, #1a1a2e, #16213e);
#             border-radius: 12px; color: white;">
#     <h1 style="margin-top: 0; font-size: 28px;">SF Crime Analysis</h1>
#     <p style="color: #b0b0c0; line-height: 1.6;">
#         An interactive exploration of two decades of crime data in San Francisco —
#         uncovering patterns across time, space, and category.
#     </p>
#     <div style="display: flex; gap: 10px; margin-top: 20px;">
#         <a href="#" style="padding: 10px 20px; background: #e94560; color: white;
#            text-decoration: none; border-radius: 6px;">Hourly patterns</a>
#         <a href="#" style="padding: 10px 20px; background: #0f3460; color: white;
#            text-decoration: none; border-radius: 6px;">Crime map</a>
#     </div>
# </div>

# %% [markdown]
# That's HTML with inline CSS styling — and it already looks like a piece of a modern website. The key things to notice:
#
# * `<div>`, `<h1>`, `<p>`, `<a>` are HTML **elements** — they define the structure (a container, a heading, a paragraph, a link)
# * The `style="..."` attributes control how things look — colors, fonts, spacing, layout
# * Everything between `<tag>` and `</tag>` is the content of that element
#
# You don't need to become an HTML/CSS expert. Your LLM will write most of it for you. But having a basic feel for what's going on will help you communicate with your LLM and debug things when they don't look right.
#
# > *Exercise 1.2*: Play with HTML.
# >
# > * Copy the code cell above and modify it. Try changing:
# >   - The title text and description
# >   - The background color (try `#2d3436` for dark gray, or `#dfe6e9` for light gray with dark text)
# >   - The button colors and labels
# >   - Add a third button
# > * Now try building something from scratch. Create a simple HTML snippet that has:
# >   - A heading with your name (or group name)
# >   - A short paragraph about your project
# >   - A list of your Personal Focus Crimes (hint: use `<ul>` and `<li>` tags — or ask your LLM)
# > * What happens if you remove a closing tag (like `</div>`)? Try it and see.
# >
# > The point isn't to master HTML — it's to get comfortable enough that the files you'll create in Part 2 don't feel alien.
#
# <div class="alert alert-block alert-info">
# It's OK to ask your LLM for help with HTML syntax. In fact, try asking it to explain what each part of the code above does — that's a great way to learn.
# </div>

# %%
from IPython.display import HTML

HTML("""
<div style="font-family: 'Helvetica Neue', Arial, sans-serif; max-width: 600px;
            padding: 30px; background: linear-gradient(135deg, #1a1a2e, #dfe6e9);
            border-radius: 12px; color: white;">
    <h1 style="margin-top: 0; font-size: 28px;">SF Crime Analysis</h1>
    <p style="color: #b0b0c0; line-height: 1.6;">
        An interactive exploration of two decades of crime data in San Francisco —
        uncovering patterns across time, space, and category.
    </p>
    <div style="display: flex; gap: 10px; margin-top: 20px;">
        <a href="#" style="padding: 10px 20px; background: #e94560; color: white;
           text-decoration: none; border-radius: 6px;">Hourly patterns</a>
        <a href="#" style="padding: 10px 20px; background: #0f3460; color: white;
           text-decoration: none; border-radius: 6px;">Crime map</a>
    </div>
</div>
""")
# Out:
# <div style="font-family: 'Helvetica Neue', Arial, sans-serif; max-width: 600px;
#             padding: 30px; background: linear-gradient(135deg, #1a1a2e, #dfe6e9);
#             border-radius: 12px; color: white;">
#     <h1 style="margin-top: 0; font-size: 28px;">SF Crime Analysis</h1>
#     <p style="color: #b0b0c0; line-height: 1.6;">
#         An interactive exploration of two decades of crime data in San Francisco —
#         uncovering patterns across time, space, and category.
#     </p>
#     <div style="display: flex; gap: 10px; margin-top: 20px;">
#         <a href="#" style="padding: 10px 20px; background: #e94560; color: white;
#            text-decoration: none; border-radius: 6px;">Hourly patterns</a>
#         <a href="#" style="padding: 10px 20px; background: #0f3460; color: white;
#            text-decoration: none; border-radius: 6px;">Crime map</a>
#     </div>
# </div>

# %% [markdown]
# ---
#
# ## Part 2: Setting Up GitHub Pages
#
# Time to actually build. [GitHub Pages](https://pages.github.com) gives you a free website at `https://USERNAME.github.io`. The way it works is simple:
#
# 1. You create a specially-named repository on GitHub.
# 2. You put HTML files in it.
# 3. GitHub serves those files to the world as a website.
#
# When you want to update your site, you change the files locally and `git push`. That's it. No server to manage, no hosting fees, no complicated build tools.
#
# <div class="alert alert-block alert-success">
# <b>Uncle Sune Philosphizes</b>: They told me to make this course AI first, and this year it's really happning. We're going crazy, you're going to be like little experimental monkeys shot into space. In the previous versions of this course, I used [Jekyll](https://jekyllrb.com), which is a static site generator built on Ruby, to create websites. Jekyll is great in that it has lots of documentation, but it's also cumbersome and it's difficult do do all the crazy Ruby installs, etc. <b><i>In 2026, I'm combining the oldschool AND newschool way</i></b>: plain HTML files (like we did back in the early 200s), pushed to GitHub. But here's the twist: You won't write the HTML. I'm making a bet that your LLM can generate better-looking HTML than Jekyll's default templates. And I hope it can help you organize the plain html files into a working static site. (Worst case, you can write the .html yourself based on some ancient tutorials, ahhahhahaahhah). If this fails spectacularly, I have a backup plan.
# </div>
#
#
#
# ### Before you start: git
#
# In order for this whole thing to work, you need to be comfortable with using Git and GitHub via the terminal. You've been doing that throughout the course, but in case you're not 100% comfortable, I recommend you go on line and watch a tutorial video. It's part of the exercise for you to find one you like.
#
# * **Milestone**: You should be comfortable with the git commands `clone`, `add`, `commit`, `push`, `pull`, and `merge`.

# %% [markdown]
# > *Exercise 2.1*: Get your site online.
# >
# > Follow these steps. The goal: by the end of this exercise, you should be able to visit `https://USERNAME.github.io` and see your page.
# >
# > **Step 1: Create the repository**
# >
# > * Go to [github.com/new](https://github.com/new) and create a new repository named **exactly** `USERNAME.github.io` (replace `USERNAME` with your actual GitHub username). For example, in my case it would be `suneman.github.io`.
# > * This exact naming convention is what tells GitHub to serve it as a website.
# > * Make sure the repository is **public** (GitHub Pages requires this for free accounts).
# > * You can initialize it with a README if you like, but it's not required.
# >
# > **Step 2: Clone it to your computer**
# >
# > Use your git skills to create a local copy of the empty repo. One way to do it is using
# >
# > `git clone https://github.com/USERNAME/USERNAME.github.io.git`
# >
# > **Step 3: Create your first page**
# >
# > Navigate into the folder and create a file called `index.html`. This is the front page of your site. You played with HTML in Part 1, so this should feel familiar. Start with something simple:
# > ```html
# > <!DOCTYPE html>
# > <html>
# > <head>
# >     <title>My Data Viz Site</title>
# > </head>
# > <body>
# >     <h1>Hello World!</h1>
# >     <p>This site will soon contain interactive data visualizations about crime in San Francisco.</p>
# > </body>
# > </html>
# > ```
# > **Step 4: Check your GitHub settings**
# >
# > Go to your repository on GitHub → **Settings** → **Pages** and make sure that github pages are set up correctly. Check the following.
# > * Source is set to **"Deploy from a branch"**
# > * Branch is **`main`**
# > * Folder is **`/ (root)`**
# >
# > **Step 5: Push to GitHub**
# >
# > ```
# > git add index.html
# > git commit -m "First page"
# > git push
# > ```
# >
# > Wait a minute or two (GitHub needs a moment to deploy your site), then visit `https://USERNAME.github.io`: you should now be able to see your site at.
# >
# > * **Woohoo**: Your page is live
#
# <div class="alert alert-block alert-info">
# Full LLM help is fine for all the setup steps. If you run into git issues or your page doesn't appear, your LLM is a great debugging partner.
# </div>

# %% [markdown]
# ### Adding content: from notebooks to web pages
#
# Your site exists but it's just a "Hello World" page. Time to fill it with the visualizations you've been building throughout the course. You have three types to work with:
#
# 1. **Matplotlib figures** (Weeks 1–4) — static plots, exported as images
# 2. **Plotly charts** (Weeks 5–6) — interactive charts with hover, zoom, and clickable legends
# 3. **Folium maps** (Week 5) — interactive maps with pan, zoom, and data layers
#
# Each exports differently. Here's how to get each type out of your notebooks and onto your website.

# %% [markdown]
# **Matplotlib** figures are static, so you export them as image files. Below are some useful commands. You can run those in the notebook where you created a useful matplotlib figure to export it:

# %%
# --- Run this in your Week 1-4 notebooks, where you have matplotlib figures ---

import matplotlib.pyplot as plt

# After creating your figure with plt.plot(), plt.bar(), fig, ax = plt.subplots(), etc:
plt.savefig("yearly_crime_trends.png", dpi=150, bbox_inches='tight')
 
# For scalable, print-quality output, use SVG instead:
# plt.savefig("yearly_crime_trends.svg", bbox_inches='tight')

# Then embed in your HTML with:
# <img src="yearly_crime_trends.png" alt="Yearly crime trends in SF" style="max-width: 100%;">
# Out:
#   Cell In[4], line 12
#     <img src="yearly_crime_trends.png" alt="Yearly crime trends in SF" style="max-width: 100%;">
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Plotly** charts are interactive, and Plotly can export them as self-contained HTML files that include all the JavaScript needed for the interactivity to work. Once again, here are some helpful commands for exporting:

# %%
# --- Run this in your Week 5 or 6 notebook, where 'fig' is your Plotly figure ---

# Option A: Self-contained file (works offline, but can be 3-5 MB)
fig.write_html("crime_hourly_interactive.html")

# Option B: Load Plotly.js from CDN (much smaller file, needs internet to view)
fig.write_html("crime_hourly_interactive.html", include_plotlyjs='cdn')

# Recommend Option B for your website — visitors will have internet,
# and the smaller file means faster page loads.

# %% [markdown]
# **Folium** maps export the same way, as self-contained HTML:

# %%
# --- Run this in your Week 5 notebook, where 'm' is your Folium map ---

m.save("sf_crime_heatmap.html")

# The resulting file contains everything: map tiles, data layers, interactivity.
# Just copy it into your repo.

# %% [markdown]
# ### Putting visualizations on your site
#
# Once you've exported your files, copy them into your `USERNAME.github.io` repository folder. You have two options for displaying them:
#
# **Option 1: Link as separate pages.** Add a link from your `index.html`:
#
# ```html
# <a href="crime_hourly_interactive.html">Explore hourly crime patterns →</a>
# ```
#
# Each visualization gets its own full-screen page. Clean and simple.
#
# **Option 2: Embed within a page using an `<iframe>`.** This lets you put a visualization inside a page alongside text and other content:
#
# ```html
# <iframe src="crime_hourly_interactive.html" width="100%" height="600" frameborder="0"></iframe>
# ```
#
# This approach is especially useful for building narrative pages with text and visualizations woven together — which is what you'll do in Week 8.
#
# For **static images** (matplotlib), just use an `<img>` tag:
#
# ```html
# <img src="images/yearly_crime_trends.png" alt="Yearly crime trends" style="max-width: 100%;">
# ```
#
# ### Organizing your files
#
# As you add exported visualizations, images, and maybe CSS files, your repo can get messy fast. A simple folder structure helps:
#
# ```
# USERNAME.github.io/
# ├── index.html
# ├── .nojekyll
# ├── visualizations/
# │   ├── crime_hourly.html
# │   ├── sf_heatmap.html
# │   └── animated_trends.html
# └── images/
#     ├── yearly_trends.png
#     └── district_ratios.svg
# ```
#
# If you use subfolders, remember to update your links: `href="visualizations/crime_hourly.html"` instead of just `href="crime_hourly.html"`.

# %% [markdown]
# > *Exercise 2.2*: Add content to your site.
# >
# > * Go back to your notebooks from Weeks 1–6 and export at least three visualizations:
# >   - One **static matplotlib figure** (saved as PNG or SVG)
# >   - One **interactive Plotly chart** (saved as HTML — try the animated chart from Week 6 or a choropleth from Week 5)
# >   - One **Folium map** (saved as HTML)
# > * Copy the exported files into your `USERNAME.github.io` repo. Use folders to keep things organized.
# > * Update your `index.html` to link to or embed each visualization. At minimum, a visitor should be able to find and interact with all three from your front page.
# > * Push to GitHub and verify everything works on the live site: images load, Plotly hover/click/zoom works, and the Folium map renders with pan and zoom.
# >
# > * **Milestone**: Your site has at least three visualizations — both static and interactive — that visitors can explore ✓
#
# <div class="alert alert-block alert-info">
# Full LLM help is fine. Focus on getting everything working.
# </div>

# %% [markdown]
# **Pro tip: Preview locally.** For a single page, you can just view index.html in browser. But as you page grows in complexity that solution doesn't work. And it gets annoying to push to GitHub and wait for deployment every time you tweak something. So a neat trick is that you can preview your site locally by running this in your terminal from inside your repo folder:
#
# ```
# python -m http.server 8000
# ```
#
# Then open `http://localhost:8000` in your browser. Changes show up instantly when you refresh — much faster than the push-and-wait cycle. Use this for rapid iteration, and only push to GitHub when you're happy with the result.

# %% [markdown]
# ---
#
# ## Part 3: Design and Polish
#
# Your site has content now, but the design probably looks like it was built in 1997. Time to fix that.
#
# In Exercise 1.1 you looked at professional data viz sites and noted design ideas you liked. Now you'll bring those ideas to life, using your LLM as a design partner. The key is not to ask once and accept whatever it gives you, but to **iterate**: prompt, evaluate, refine, repeat.
# * **Hint**: This will work better if you use a frontier model. (To test if the exercise for today was even feasible, I started Claude Code in my `suneman.github.io` and asked it to go online, find info about me, and then create a website based on available info. The first attempt was pretty good: https://suneman.github.io)

# %% [markdown]
# ### The art of the prompt
#
# Not all prompts are created equal. Here's the same request at three levels of specificity:
#
# **Level 1 — Vague:**
# > *"Make me a website for data visualizations."*
#
# You'll get something generic and forgettable. The LLM has to guess everything about what you want.
#
# **Level 2 — Directional:**
# > *"Create an HTML page for a data science portfolio with a dark theme and cards that link to my visualizations."*
#
# Better. The LLM knows the purpose, has a color direction, and a structural element to work with.
#
# **Level 3 — Specific:**
# > *"Create a single-page HTML file for a data science portfolio about San Francisco crime analysis. Use a dark background (#1a1a2e) with light text and teal (#16c79a) accents. Include a full-width header with the title 'SF Crime: Two Decades of Data', a two-sentence introduction, and a responsive grid of cards — each card should have a title, a one-line description, and a link. Add subtle hover effects on the cards. All CSS should be in an embedded `<style>` tag. The page should work on mobile."*
#
# Something like this might give you something close to professional quality on the first try. The key is being specific about **structure** (what sections, how they're laid out), **style** (colors, fonts, effects), and **constraints** (single file, embedded CSS, responsive).
#
# <div class="alert alert-block alert-info">
# <b>I don't want you to AI generate the structure AND I don't want you to use AI to create the text</b>. You should come up with the right structure for your project, and you should write the text. I can't tell you how tired I am of reading AI generated generic sentences. You add that stuff ... but it's cool you have the AI come up with an exceptional layout and filler text to get you started.
# </div>
#
# You don't need to nail it on the first prompt. Start with something reasonable, look at the result, and refine: *"Make the cards wider"*, *"The header is too tall, shrink it"*, *"Change the accent color to coral"*, *"Add more whitespace between sections"*. Each round gets you closer to what you actually want.

# %% [markdown]
# > *Exercise 3.1*: Design your site.
# >
# > * Write an LLM prompt for your site design. Be as specific as you can — refer back to the design ideas you noted in Exercise 1.1.
# > * Generate the HTML, replace your `index.html`, and preview locally (`python -m http.server 8000`).
# > * Now iterate. Do at least **three rounds** of refinement:
# >   - Round 1: Fix the obvious problems (wrong colors, broken layout, missing links to your visualizations)
# >   - Round 2: Improve the aesthetics (spacing, typography, visual hierarchy)
# >   - Round 3: Add finishing touches (hover effects, smooth scrolling, a footer, responsive mobile layout)
# > * **Important: commit after each round** with a descriptive message:
# >   ```
# >   git add -A
# >   git commit -m "Add dark theme with card grid layout"
# >   ```
# >   ```
# >   git add -A
# >   git commit -m "Improve spacing and typography"
# >   ```
# >   ```
# >   git add -A
# >   git commit -m "Add hover effects and mobile responsiveness"
# >   ```
# >   This gives you a history of your design evolution and lets you roll back if a change breaks something. One of the underappreciated superpowers of using git for websites is that your entire design history is saved — you can always go back.
# > * Make sure all your visualization links still work after the redesign.
# > * Push the final version to GitHub.
# >
# > Some optional things to try if you want to go further:
# > * A dark mode toggle
# > * A sticky navigation bar that stays at the top as you scroll
# > * A subtle CSS animation (fade-in on page load, or hover transitions on cards)
# > * Check your site on your phone — does it look OK? If not, ask your LLM about responsive design.
# >
#
# <div class="alert alert-block alert-info">
# Go wild with LLM help for the <b>design</b> of your website. This is the big experiment we're doing in this class this year. I hope it's awesome. Can you use modern web design — without needing to become a web developer? And the commit-after-each-round workflow is important though: do that part yourself.
# </div>

# %% [markdown]
# > *Exercise 3.2*: Look ahead.
# >
# > Next week, you'll use this site to create a **data story** — a narrative visualization piece about SF crime, written for a general audience. Think of it as a short magazine article with interactive graphics embedded in the page.
# >
# > To prepare, start thinking about:
# >
# > * Which findings from Weeks 1–6 surprised you or your group the most?
# > * Which of your visualizations told the most compelling story?
# > * What would you want a reader who knows nothing about this dataset to take away?
# > * Remember the Segel & Heer reading from Week 6 — you'll be putting those narrative visualization concepts into practice.
# >
# > You don't need to write anything yet. Just let the ideas percolate.
#
# <div class="alert alert-block alert-info">
# This is thinking, not coding — use your human brain.
# </div>

# %% [markdown]
# ---
#
# ## You've Completed Week 7!
#
# This week was different — no crime data wrangling, no new plot types, no heavy reading. Instead, you've built the infrastructure for sharing your work with the world. You now have:
#
# - A live website at `USERNAME.github.io` that anyone can visit
# - The ability to export matplotlib, Plotly, and Folium visualizations from your notebooks onto the web
# - A professional-looking site with clear navigation to your content
# - Experience using iterative LLM prompting to design web pages
#
# **Key takeaways:**
# - The web is the natural medium for interactive data visualization. Publishing your work makes it accessible in a way that a notebook on your laptop never can.
# - Exporting visualizations is trivially easy — `plt.savefig()`, `fig.write_html()`, `m.save()`. The barrier between "I made a cool chart" and "anyone in the world can interact with it" is just a `git push`.
# - Good design comes from iteration, not inspiration. Start with something, evaluate it critically, refine, repeat. The same applies to LLM prompts — specificity and iteration beat hoping for a perfect first try.
# - Git isn't just for code. Using it for your website gives you version history, easy rollback, and free hosting — a workflow worth keeping beyond this course.
#
# Next week, you'll put this site to work. Everything from Weeks 1–6 — the data wrangling, the visualizations, the interactive charts, the narrative theory from Segel & Heer — comes together in a published data story. Your website is the canvas; next week you paint on it.
#
# If you want to go further:
# - Look at how [The Pudding](https://github.com/the-pudding) structures their projects on GitHub — they open-source everything.
# - Try adding a custom [404 page](https://docs.github.com/en/pages/getting-started-with-github-pages/creating-a-custom-404-page-for-your-github-pages-site) — make it fun or on-theme.
# - Experiment with [CSS animations](https://developer.mozilla.org/en-US/docs/Web/CSS/CSS_animations/Using_CSS_animations) to add subtle polish (fade-ins, slide-ups on scroll).
